# %%
import os
import glob

from IPython.display import Image,display

# %%
HOME = '/kaggle/working/'
print(HOME)
# Out:
# /kaggle/working/

# %%
# !pip install ultralytics==8.0.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.8/219.8 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.7 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6170.1/8062.4 GB disk)

# %%
ls /kaggle/input
# Out:
# trafficdata/

# %%
ls /kaggle/input/trafficdata
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  train/  valid/

# %%
# !cat /kaggle/input/trafficdata/data.yaml
# Out:
# train: "/kaggle/input/trafficdata/train/images"
# val: "/kaggle/input/trafficdata/valid/images"
#
#
# nc: 45
# ...

# %%
pip install --upgrade pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 77.6 MB/s eta 0:00:00ta 0:00:01
# ...
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.0.0
#     Uninstalling pillow-11.0.0:
#       Successfully uninstalled pillow-11.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.4 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade scikit-learn matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 88.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 97.2 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.5
#     Uninstalling matplotlib-3.7.5:
#       Successfully uninstalled matplotlib-3.7.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.6.1 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade "pillow<10.0"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 68.0 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 0.2.2 requires pillow<12.0.0,>=10.0.0, but you have pillow 9.5.0 which is incompatible.
# scikit-image 0.25.0 requires pillow>=10.1, but you have pillow 9.5.0 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import os

dataset_path = "/kaggle/input/trafficdata/train/images"  

# Get a sample image
sample_image = os.listdir(dataset_path)[0]  # Get first image
image_path = os.path.join(dataset_path, sample_image)

# Read image with OpenCV
image = cv2.imread(image_path)
height, width, channels = image.shape  # Get dimensions

print(f"Image Size: {width}x{height}, Channels: {channels}")
# Out:
# Image Size: 640x640, Channels: 3

# %%
pip install wandb -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import wandb
wandb.login(key="941e5e68cfea673d96778c0376ee1da74f9e8879")
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mona-tarek-mohamed1 (mona-tarek-mohamed1-faculty-of-engineering). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import os

train_images = os.listdir("/kaggle/input/trafficdata/train/images")
valid_images = os.listdir("/kaggle/input/trafficdata/valid/images")

print(f"Training images: {len(train_images)}")
print(f"Validation images: {len(valid_images)}")
# Out:
# Training images: 4365
# Validation images: 1455

# %%
# !ls /kaggle/input/
# Out:
# trafficdata

# %%
pip install --upgrade ultralytics torch torchvision torchaudio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.3/949.3 kB 38.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 2.2 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.7 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 61.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.2 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 3.0 MB/s eta 0:00:000:00:0100:01
# ...

# %%
# !yolo train model=yolov8n.pt data=/kaggle/input/trafficdata/data.yaml epochs=150 batch=16 workers=0 cache=False
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|███████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 167MB/s]
# Ultralytics 8.3.92 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # Evaluate

# %%
from ultralytics import YOLO

model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt", weights_only=True)  
metrics = model.val(data="/kaggle/working/dataset/data.yaml")
print(metrics)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-c07076b831bb> in <cell line: 3>()
#       1 from ultralytics import YOLO
#       2
# ----> 3 model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt", weights_only=True)
#       4 metrics = model.val(data="/kaggle/working/dataset/data.yaml")
#       5 print(metrics)
#
# TypeError: YOLO.__init__() got an unexpected keyword argument 'weights_only'

# %%
import os

pt_path = "/kaggle/working/runs/detect/train/weights/best.pt"
print("File Exists:", os.path.exists(pt_path))
print("File Size:", os.path.getsize(pt_path) if os.path.exists(pt_path) else "File not found")
# Out:
# File Exists: True
# File Size: 6279779

# %% [markdown]
# #  Convert to ONNX Format

# %%
# !yolo export model=/kaggle/working/runs/detect/train/weights/best.pt format=onnx
# Out:
# Ultralytics 8.3.92 🚀 Python-3.10.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 72 layers, 3,014,423 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/kaggle/working/runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 49, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['onnxslim', 'onnxruntime'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 kB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 309.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 199.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 293.7 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 4.9s, installed 2 packages: ['onnxslim', 'onnxruntime']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ...

# %%
os.listdir("/kaggle/working/runs/detect/train/weights")
# Out:
# ['best.onnx', 'last.pt', 'best.pt']

# %% [markdown]
# # Test

# %%
# !pip uninstall -y ultralytics
# Out:
# Found existing installation: ultralytics 8.3.92
# Uninstalling ultralytics-8.3.92:
#   Successfully uninstalled ultralytics-8.3.92

# %%
# !rm -rf /usr/local/lib/python3.10/dist-packages/ultralytics

# %%
# !pip install --force-reinstall ultralytics --no-cache-dir
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 243.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 262.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 253.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 292.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 271.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.3/949.3 kB 98.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 268.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 203.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 93.9 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 232.7 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 242.9 MB/s eta 0:00:00
# ...

# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# 8.0.0

# %%
from ultralytics import YOLO

# Load the trained model
model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt")

# Run inference on a test image
image_path = "/kaggle/input/trafficdata/valid/images/000220_jpg.rf.a335f748fd63983294f009c8e3c11fbf.jpg"  # Replace with an actual image path
results = model(image_path)

# Display the results
import cv2
import matplotlib.pyplot as plt

image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

for r in results:
    im_array = r.plot()
    plt.imshow(im_array)
    plt.axis("off")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-48-bf97b22133f8> in <cell line: 4>()
#       2
#       3 # Load the trained model
# ----> 4 model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt")
#       5
#       6 # Run inference on a test image
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py in __init__(self, model, type)
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py in _load(self, weights)
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py in attempt_load_one_weight(weight, device, inplace, fuse)
#     339                     return self.forward(x)["one2many"]
#     340                 return self.forward(x)[0] if isinstance(m, (Segment, Pose, OBB)) else self.forward(x)
# --> 341
# ...
